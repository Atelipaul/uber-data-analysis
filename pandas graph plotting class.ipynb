# %%
# matplotlib and seaborn are used for visualization in python

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/waleolajumoke/data/main/dm_office_sales.csv")
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
# creating plot

x = np.arange(1,6)
y = x * 2
plt.xlabel("X Axis")    # labelling
plt.ylabel("Y Axis")
plt.title("Sample Graph")
plt.plot(x,y)          #plotting
plt.savefig("my-sample-graph.jpg")  # saving the graph

# %%
plt.figure(figsize=(10,4))   # resizing
x = np.arange(1,6)
y = x * 2
plt.xlabel("X Axis")    # labelling
plt.ylabel("Y Axis")
plt.title("Sample Graph")
plt.plot(x,y)          #plotting
plt.savefig("my-sample-graph.jpg")  # saving the graph

# %%
# stying your graphg
plt.figure(figsize=(10,4))
plt.plot(x,y, color="red", marker="o", markersize=10, label="2020 sales")
plt.plot(x , x**3, color="green", marker="+", label="2021 sales")
plt.legend()

# %%
# checking relationship or corrolation
plt.figure(figsize=(10,4))
sns.scatterplot(df, x="sales", y="salary")
# Out:
# <Axes: xlabel='sales', ylabel='salary'>

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(df, x="sales", y="salary", hue="division")
# Out:
# <Axes: xlabel='sales', ylabel='salary'>

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(df, x="sales", y="salary", hue="level of education")
# Out:
# <Axes: xlabel='sales', ylabel='salary'>

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(df, x="sales", y="salary", hue="level of education", palette="viridis")
# Out:
# <Axes: xlabel='sales', ylabel='salary'>

# %%
# distrbution
sns.histplot(df,x="salary")
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
sns.displot(df, x="salary")
# Out:
# C:\Users\supa_\anaconda3 Paul Ateli\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# category plot
plt.figure(figsize=(10,4))
sns.countplot(df, x="division")
# Out:
# <Axes: xlabel='division', ylabel='count'>

# %%
plt.figure(figsize=(10,4))
sns.countplot(df, x="level of education")
# Out:
# <Axes: xlabel='level of education', ylabel='count'>

# %%
plt.figure(figsize=(10,4))
sns.barplot(df, x="level of education", y="salary")
# Out:
# <Axes: xlabel='level of education', ylabel='salary'>

# %%
plt.figure(figsize=(10,4))
sns.countplot(df, x="level of education", hue="training level")
# Out:
# <Axes: xlabel='level of education', ylabel='count'>

# %%
plt.figure(figsize=(10,4))
sns.countplot(df, x="level of education", hue="work experience")
# Out:
# <Axes: xlabel='level of education', ylabel='count'>
